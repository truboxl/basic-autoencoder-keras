# %%
import tensorflow as tf
Model           = tf.keras.models.Model
Input           = tf.keras.layers.Input
Dense           = tf.keras.layers.Dense
Conv2D          = tf.keras.layers.Conv2D
MaxPooling2D    = tf.keras.layers.MaxPooling2D
UpSampling2D    = tf.keras.layers.UpSampling2D
save_model      = tf.keras.models.save_model
load_model      = tf.keras.models.load_model
#load_img        = tf.keras.preprocessing.image.load_img # pip install pillow or import PIL
#img_to_array    = tf.keras.preprocessing.image.img_to_array
TensorBoard     = tf.keras.callbacks.TensorBoard
ModelCheckpoint = tf.keras.callbacks.ModelCheckpoint

# %%
# https://www.pyimagesearch.com/2018/12/31/keras-conv2d-and-convolutional-layers/
# Conv2D(batch_size, (input_shape), activation, padding) # more batch size in deeper layer
# MaxPooling2D((input_shape), padding) # padding 'valid' = no padding, padding 'same' = preserve dimension + padding

# Autoencoder Architecture
input_img = Input(shape=(64, 64, 3)) # change this to other than 28*28 may show "multiple" shape
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
#x = Dropout(0.20)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x) # at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
#x = Dropout(0.20)(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) # may want to intentionally drop padding here for other shape
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded, name='autoencoder')
autoencoder.compile(optimizer='adam', loss='binary_crossentropy') # use binary_crossentropy, mean_squared_error doesnt work

# Encoder Model
encoder = Model(input_img, encoded, name='encoder')

# Decoder Architecture
Dlayer_input = Input(shape=(8,8,16)) # use model.summary() to check
x = autoencoder.layers[-7](Dlayer_input)
x = autoencoder.layers[-6](x)
x = autoencoder.layers[-5](x)
x = autoencoder.layers[-4](x)
x = autoencoder.layers[-3](x)
x = autoencoder.layers[-2](x)
Dlayer_output = autoencoder.layers[-1](x) # extract last layer

# Decoder Model
decoder = Model(Dlayer_input, Dlayer_output, name='decoder')

# %%
autoencoder.summary()
encoder.summary()
decoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         867
# =================================================================
# Total params: 17,987
# Trainable params: 17,987
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 16)          0
# =================================================================
# Total params: 7,840
# Trainable params: 7,840
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8, 8, 16)]        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 16)        2320
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         867
# =================================================================
# Total params: 10,147
# Trainable params: 10,147
# Non-trainable params: 0
# _________________________________________________________________

# %%
def make_square(img):
    cols,rows = img.size
    
    if rows>cols:
        pad = (rows-cols)/4
        img = img.crop((0, pad, cols, cols+pad)) # left, up, right, down
    else:
        pad = (cols-rows)/4
        img = img.crop((pad, 0, rows+pad, rows))
    
    return img # make centered square image

# %%
# %%time
# Check training dataset image
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display

path_train = r"D:\Public\fyp-code\datasets\coco\train2017-2"

train_data = []

for img in sorted(os.listdir(path_train)):
    #print(img) # show which image file currently used
    
    # Keras builtin (not used)
    #x = load_img(os.path.join(path_train,img), target_size=(128,128), color_mode='grayscale') 
    #x = img_to_array(x)
    
    # PIL (use this)
    x = Image.open(os.path.join(path_train,img))
    display(x) # show training image
    print("Original image size is " + str(x.size))
    x = make_square(x)
    display(x) # show square image
    print("Squared image size is " + str(x.size))
    x = x.resize((64,64)) # TAKE NOTE
    x = np.asarray(x)
    x = x.astype('float32')/255
    train_data.append(np.asarray(x)) # can take a long time
    print(str(len(train_data)) + " of " + str(len(os.listdir(path_train))))
    break

print("train_data type is " + str(type(train_data)))
print("train_data shape is "+ str(np.asarray(train_data).shape)) # type list has no shape, must be in type array # (1, 128, 128, 3)
print("image type in train_data is " + str(type(train_data[0])))
plt.imshow(np.squeeze(train_data[0])) # show resized 1st image
plt.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x263EAA3DC48>
# Original image size is (640, 480)
# <PIL.Image.Image image mode=RGB size=480x480 at 0x263EA9C43C8>
# Squared image size is (480, 480)
# 1 of 14785
# train_data type is <class 'list'>
# train_data shape is (1, 64, 64, 3)
# image type in train_data is <class 'numpy.ndarray'>
# Wall time: 627 ms

# %%
# Refer "Dataset Preprocess to Pickle - COCO train2017.ipynb" for data preprocess
# We will directly load preprocessed datasets rather than load jpg one by one

# %%
# %%time
import pickle as pkl

with open("datasets_coco_train2017_64.pkl", 'rb') as handle:
    train_data = pkl.load(handle)

print("Done")

with open("datasets_coco_test2017_64.pkl", 'rb') as handle:
    test_data = pkl.load(handle)

print("Done")

with open("datasets_coco_val2017_64.pkl", 'rb') as handle:
    val_data = pkl.load(handle)

print("Done")
# Out:
# Done
# Done
# Done
# Wall time: 15.8 s

# %%
# %%time
#train_data = np.reshape(train_data, (len(train_data), 128, 128, 3))
#test_data = np.reshape(test_data, (len(test_data), 128, 128, 3))
#val_data = np.reshape(val_data, (len(val_data), 128, 128, 3))
print(train_data.shape)
print(test_data.shape)
print(val_data.shape)
# Out:
# (14785, 64, 64, 3)
# (5083, 64, 64, 3)
# (625, 64, 64, 3)
# Wall time: 999 µs

# %%
# %%time
#import os
#os.listdir("autoencoderv5/checkpoint")

# Resume by load model (example)
#autoencoder = load_model("autoencoderv5/checkpoint/model.02-0.53.h5") # use this
#latest = tf.train.latest_checkpoint("autoencoderv5/checkpoint") # TODO
# Out:
# Wall time: 0 ns

# %%
# %%time
import os

try:
    os.makedirs("autoencoderv5/logs")
except Exception:
    pass

try:
    os.makedirs("autoencoderv5/checkpoint")
except Exception:
    pass

# Run this in a terminal
#tensorboard --logdir=autoencoderv5/logs

callbacks=[
    TensorBoard(log_dir='autoencoderv5/logs'),
    ModelCheckpoint(filepath='autoencoderv5/checkpoint/model.{epoch:003d}-{val_loss:.3f}.h5',
                    verbose=1, save_best_only=True, mode='min')
]

# Fit data # If it takes a long time to show Epoch 1, check your input shape # WARINING: RAM will rise
autoencoder.fit(train_data, train_data,
                epochs=100, batch_size=32, shuffle=True,
                validation_data=(test_data, test_data),
                callbacks=callbacks)
# Out:
# Epoch 1/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5761
# Epoch 00001: val_loss improved from inf to 0.55982, saving model to autoencoderv5/checkpoint/model.01-0.560.h5
# 463/463 [==============================] - 251s 541ms/step - loss: 0.5761 - val_loss: 0.5598
# Epoch 2/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5582
# Epoch 00002: val_loss improved from 0.55982 to 0.55583, saving model to autoencoderv5/checkpoint/model.02-0.556.h5
# 463/463 [==============================] - 207s 447ms/step - loss: 0.5582 - val_loss: 0.5558
# Epoch 3/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5558
# Epoch 00003: val_loss improved from 0.55583 to 0.55435, saving model to autoencoderv5/checkpoint/model.03-0.554.h5
# 463/463 [==============================] - 191s 413ms/step - loss: 0.5558 - val_loss: 0.5543
# Epoch 4/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5541
# Epoch 00004: val_loss did not improve from 0.55435
# 463/463 [==============================] - 183s 396ms/step - loss: 0.5540 - val_loss: 0.5548
# Epoch 5/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5527
# Epoch 00005: val_loss improved from 0.55435 to 0.55200, saving model to autoencoderv5/checkpoint/model.05-0.552.h5
# 463/463 [==============================] - 188s 405ms/step - loss: 0.5527 - val_loss: 0.5520
# Epoch 6/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5517
# Epoch 00006: val_loss improved from 0.55200 to 0.55070, saving model to autoencoderv5/checkpoint/model.06-0.551.h5
# 463/463 [==============================] - 190s 410ms/step - loss: 0.5517 - val_loss: 0.5507
# Epoch 7/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5510
# Epoch 00007: val_loss improved from 0.55070 to 0.55019, saving model to autoencoderv5/checkpoint/model.07-0.550.h5
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5510 - val_loss: 0.5502
# Epoch 8/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5504
# Epoch 00008: val_loss did not improve from 0.55019
# 463/463 [==============================] - 177s 382ms/step - loss: 0.5504 - val_loss: 0.5513
# Epoch 9/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5501
# Epoch 00009: val_loss improved from 0.55019 to 0.54976, saving model to autoencoderv5/checkpoint/model.09-0.550.h5
# 463/463 [==============================] - 181s 391ms/step - loss: 0.5501 - val_loss: 0.5498
# Epoch 10/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5495
# Epoch 00010: val_loss improved from 0.54976 to 0.54904, saving model to autoencoderv5/checkpoint/model.10-0.549.h5
# 463/463 [==============================] - 182s 394ms/step - loss: 0.5495 - val_loss: 0.5490
# Epoch 11/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5492
# Epoch 00011: val_loss did not improve from 0.54904
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5492 - val_loss: 0.5499
# Epoch 12/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5488
# Epoch 00012: val_loss did not improve from 0.54904
# 463/463 [==============================] - 180s 389ms/step - loss: 0.5488 - val_loss: 0.5491
# Epoch 13/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5485
# Epoch 00013: val_loss improved from 0.54904 to 0.54812, saving model to autoencoderv5/checkpoint/model.13-0.548.h5
# 463/463 [==============================] - 183s 395ms/step - loss: 0.5485 - val_loss: 0.5481
# Epoch 14/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 00014: val_loss improved from 0.54812 to 0.54779, saving model to autoencoderv5/checkpoint/model.14-0.548.h5
# 463/463 [==============================] - 209s 452ms/step - loss: 0.5480 - val_loss: 0.5478
# Epoch 15/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5478
# Epoch 00015: val_loss did not improve from 0.54779
# 463/463 [==============================] - 198s 428ms/step - loss: 0.5478 - val_loss: 0.5486
# Epoch 16/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5475
# Epoch 00016: val_loss did not improve from 0.54779
# 463/463 [==============================] - 200s 431ms/step - loss: 0.5475 - val_loss: 0.5540
# Epoch 17/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5473
# Epoch 00017: val_loss improved from 0.54779 to 0.54726, saving model to autoencoderv5/checkpoint/model.17-0.547.h5
# 463/463 [==============================] - 217s 469ms/step - loss: 0.5473 - val_loss: 0.5473
# Epoch 18/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00018: val_loss improved from 0.54726 to 0.54639, saving model to autoencoderv5/checkpoint/model.18-0.546.h5
# 463/463 [==============================] - 207s 448ms/step - loss: 0.5470 - val_loss: 0.5464
# Epoch 19/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5467
# Epoch 00019: val_loss did not improve from 0.54639
# 463/463 [==============================] - 187s 405ms/step - loss: 0.5467 - val_loss: 0.5476
# Epoch 20/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00020: val_loss improved from 0.54639 to 0.54603, saving model to autoencoderv5/checkpoint/model.20-0.546.h5
# 463/463 [==============================] - 183s 395ms/step - loss: 0.5464 - val_loss: 0.5460
# Epoch 21/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 00021: val_loss improved from 0.54603 to 0.54564, saving model to autoencoderv5/checkpoint/model.21-0.546.h5
# 463/463 [==============================] - 186s 401ms/step - loss: 0.5462 - val_loss: 0.5456
# Epoch 22/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00022: val_loss did not improve from 0.54564
# 463/463 [==============================] - 183s 396ms/step - loss: 0.5460 - val_loss: 0.5616
# Epoch 23/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 00023: val_loss did not improve from 0.54564
# 463/463 [==============================] - 186s 402ms/step - loss: 0.5463 - val_loss: 0.5460
# Epoch 24/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5456
# Epoch 00024: val_loss improved from 0.54564 to 0.54508, saving model to autoencoderv5/checkpoint/model.24-0.545.h5
# 463/463 [==============================] - 183s 396ms/step - loss: 0.5456 - val_loss: 0.5451
# Epoch 25/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5455
# Epoch 00025: val_loss did not improve from 0.54508
# 463/463 [==============================] - 183s 395ms/step - loss: 0.5455 - val_loss: 0.5454
# Epoch 26/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00026: val_loss did not improve from 0.54508
# 463/463 [==============================] - 184s 398ms/step - loss: 0.5454 - val_loss: 0.5525
# Epoch 27/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00027: val_loss improved from 0.54508 to 0.54474, saving model to autoencoderv5/checkpoint/model.27-0.545.h5
# 463/463 [==============================] - 183s 394ms/step - loss: 0.5454 - val_loss: 0.5447
# Epoch 28/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5451
# Epoch 00028: val_loss improved from 0.54474 to 0.54465, saving model to autoencoderv5/checkpoint/model.28-0.545.h5
# 463/463 [==============================] - 182s 394ms/step - loss: 0.5451 - val_loss: 0.5446
# Epoch 29/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5450
# Epoch 00029: val_loss improved from 0.54465 to 0.54447, saving model to autoencoderv5/checkpoint/model.29-0.544.h5
# 463/463 [==============================] - 182s 394ms/step - loss: 0.5449 - val_loss: 0.5445
# Epoch 30/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5448
# Epoch 00030: val_loss did not improve from 0.54447
# 463/463 [==============================] - 184s 397ms/step - loss: 0.5448 - val_loss: 0.5453
# Epoch 31/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5448
# Epoch 00031: val_loss improved from 0.54447 to 0.54428, saving model to autoencoderv5/checkpoint/model.31-0.544.h5
# 463/463 [==============================] - 199s 430ms/step - loss: 0.5448 - val_loss: 0.5443
# Epoch 32/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5446
# Epoch 00032: val_loss did not improve from 0.54428
# 463/463 [==============================] - 219s 473ms/step - loss: 0.5446 - val_loss: 0.5479
# Epoch 33/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5446
# Epoch 00033: val_loss improved from 0.54428 to 0.54412, saving model to autoencoderv5/checkpoint/model.33-0.544.h5
# 463/463 [==============================] - 227s 490ms/step - loss: 0.5446 - val_loss: 0.5441
# Epoch 34/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5444
# Epoch 00034: val_loss improved from 0.54412 to 0.54411, saving model to autoencoderv5/checkpoint/model.34-0.544.h5
# 463/463 [==============================] - 262s 566ms/step - loss: 0.5444 - val_loss: 0.5441
# Epoch 35/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5443
# Epoch 00035: val_loss did not improve from 0.54411
# 463/463 [==============================] - 270s 583ms/step - loss: 0.5443 - val_loss: 0.5442
# Epoch 36/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5442
# Epoch 00036: val_loss improved from 0.54411 to 0.54371, saving model to autoencoderv5/checkpoint/model.36-0.544.h5
# 463/463 [==============================] - 262s 565ms/step - loss: 0.5442 - val_loss: 0.5437
# Epoch 37/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5441
# Epoch 00037: val_loss did not improve from 0.54371
# 463/463 [==============================] - 212s 457ms/step - loss: 0.5441 - val_loss: 0.5438
# Epoch 38/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5440
# Epoch 00038: val_loss did not improve from 0.54371
# 463/463 [==============================] - 237s 512ms/step - loss: 0.5440 - val_loss: 0.5444
# Epoch 39/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5439
# Epoch 00039: val_loss did not improve from 0.54371
# 463/463 [==============================] - 207s 447ms/step - loss: 0.5439 - val_loss: 0.5439
# Epoch 40/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5439
# Epoch 00040: val_loss did not improve from 0.54371
# 463/463 [==============================] - 195s 421ms/step - loss: 0.5439 - val_loss: 0.5451
# Epoch 41/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5437
# Epoch 00041: val_loss improved from 0.54371 to 0.54322, saving model to autoencoderv5/checkpoint/model.41-0.543.h5
# 463/463 [==============================] - 195s 422ms/step - loss: 0.5437 - val_loss: 0.5432
# Epoch 42/100
# 462/463 [============================>.] - ETA: 2s - loss: 0.5437
# Epoch 00042: val_loss did not improve from 0.54322
# 463/463 [==============================] - 1248s 3s/step - loss: 0.5437 - val_loss: 0.5434
# Epoch 43/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5436
# Epoch 00043: val_loss improved from 0.54322 to 0.54296, saving model to autoencoderv5/checkpoint/model.43-0.543.h5
# 463/463 [==============================] - 184s 396ms/step - loss: 0.5436 - val_loss: 0.5430
# Epoch 44/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5435
# Epoch 00044: val_loss did not improve from 0.54296
# 463/463 [==============================] - 191s 414ms/step - loss: 0.5435 - val_loss: 0.5434
# Epoch 45/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5434
# Epoch 00045: val_loss did not improve from 0.54296
# 463/463 [==============================] - 188s 407ms/step - loss: 0.5434 - val_loss: 0.5432
# Epoch 46/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5434
# Epoch 00046: val_loss did not improve from 0.54296
# 463/463 [==============================] - 197s 426ms/step - loss: 0.5434 - val_loss: 0.5448
# Epoch 47/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5433
# Epoch 00047: val_loss did not improve from 0.54296
# 463/463 [==============================] - 202s 437ms/step - loss: 0.5433 - val_loss: 0.5442
# Epoch 48/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5432
# Epoch 00048: val_loss did not improve from 0.54296
# 463/463 [==============================] - 200s 432ms/step - loss: 0.5432 - val_loss: 0.5431
# Epoch 49/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5431
# Epoch 00049: val_loss improved from 0.54296 to 0.54269, saving model to autoencoderv5/checkpoint/model.49-0.543.h5
# 463/463 [==============================] - 197s 425ms/step - loss: 0.5431 - val_loss: 0.5427
# Epoch 50/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5431
# Epoch 00050: val_loss did not improve from 0.54269
# 463/463 [==============================] - 194s 418ms/step - loss: 0.5431 - val_loss: 0.5483
# Epoch 51/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5431
# Epoch 00051: val_loss did not improve from 0.54269
# 463/463 [==============================] - 191s 413ms/step - loss: 0.5431 - val_loss: 0.5476
# Epoch 52/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5430
# Epoch 00052: val_loss did not improve from 0.54269
# 463/463 [==============================] - 191s 412ms/step - loss: 0.5430 - val_loss: 0.5460
# Epoch 53/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5429
# Epoch 00053: val_loss did not improve from 0.54269
# 463/463 [==============================] - 188s 405ms/step - loss: 0.5429 - val_loss: 0.5431
# Epoch 54/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5428
# Epoch 00054: val_loss improved from 0.54269 to 0.54228, saving model to autoencoderv5/checkpoint/model.54-0.542.h5
# 463/463 [==============================] - 179s 388ms/step - loss: 0.5428 - val_loss: 0.5423
# Epoch 55/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5428
# Epoch 00055: val_loss did not improve from 0.54228
# 463/463 [==============================] - 177s 381ms/step - loss: 0.5428 - val_loss: 0.5426
# Epoch 56/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5427
# Epoch 00056: val_loss did not improve from 0.54228
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5427 - val_loss: 0.5431
# Epoch 57/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5426
# Epoch 00057: val_loss did not improve from 0.54228
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5426 - val_loss: 0.5624
# Epoch 58/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5434
# Epoch 00058: val_loss did not improve from 0.54228
# 463/463 [==============================] - 182s 394ms/step - loss: 0.5434 - val_loss: 0.5425
# Epoch 59/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5425
# Epoch 00059: val_loss did not improve from 0.54228
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5425 - val_loss: 0.5425
# Epoch 60/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5425
# Epoch 00060: val_loss did not improve from 0.54228
# 463/463 [==============================] - 178s 384ms/step - loss: 0.5425 - val_loss: 0.5436
# Epoch 61/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5424
# Epoch 00061: val_loss improved from 0.54228 to 0.54187, saving model to autoencoderv5/checkpoint/model.61-0.542.h5
# 463/463 [==============================] - 178s 384ms/step - loss: 0.5424 - val_loss: 0.5419
# Epoch 62/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5424
# Epoch 00062: val_loss did not improve from 0.54187
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5424 - val_loss: 0.5422
# Epoch 63/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5424
# Epoch 00063: val_loss did not improve from 0.54187
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5424 - val_loss: 0.5421
# Epoch 64/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5424
# Epoch 00064: val_loss did not improve from 0.54187
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5424 - val_loss: 0.5420
# Epoch 65/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5422
# Epoch 00065: val_loss did not improve from 0.54187
# 463/463 [==============================] - 174s 377ms/step - loss: 0.5422 - val_loss: 0.5429
# Epoch 66/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5422
# Epoch 00066: val_loss improved from 0.54187 to 0.54180, saving model to autoencoderv5/checkpoint/model.66-0.542.h5
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5422 - val_loss: 0.5418
# Epoch 67/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5421
# Epoch 00067: val_loss did not improve from 0.54180
# 463/463 [==============================] - 171s 368ms/step - loss: 0.5421 - val_loss: 0.5421
# Epoch 68/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5421
# Epoch 00068: val_loss did not improve from 0.54180
# 463/463 [==============================] - 171s 369ms/step - loss: 0.5421 - val_loss: 0.5425
# Epoch 69/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5420
# Epoch 00069: val_loss did not improve from 0.54180
# 463/463 [==============================] - 170s 368ms/step - loss: 0.5420 - val_loss: 0.5432
# Epoch 70/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5420
# Epoch 00070: val_loss did not improve from 0.54180
# 463/463 [==============================] - 172s 373ms/step - loss: 0.5420 - val_loss: 0.5458
# Epoch 71/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5420
# Epoch 00071: val_loss did not improve from 0.54180
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5420 - val_loss: 0.5419
# Epoch 72/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5418
# Epoch 00072: val_loss did not improve from 0.54180
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5419 - val_loss: 0.5418
# Epoch 73/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5419
# Epoch 00073: val_loss improved from 0.54180 to 0.54155, saving model to autoencoderv5/checkpoint/model.73-0.542.h5
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5419 - val_loss: 0.5416
# Epoch 74/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5418
# Epoch 00074: val_loss improved from 0.54155 to 0.54140, saving model to autoencoderv5/checkpoint/model.74-0.541.h5
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5418 - val_loss: 0.5414
# Epoch 75/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5418
# Epoch 00075: val_loss did not improve from 0.54140
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5418 - val_loss: 0.5427
# Epoch 76/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5418
# Epoch 00076: val_loss did not improve from 0.54140
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5417 - val_loss: 0.5418
# Epoch 77/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5417
# Epoch 00077: val_loss did not improve from 0.54140
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5417 - val_loss: 0.5414
# Epoch 78/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5417
# Epoch 00078: val_loss did not improve from 0.54140
# 463/463 [==============================] - 169s 365ms/step - loss: 0.5417 - val_loss: 0.5821
# Epoch 79/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5437
# Epoch 00079: val_loss did not improve from 0.54140
# 463/463 [==============================] - 170s 366ms/step - loss: 0.5437 - val_loss: 0.5416
# Epoch 80/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5417
# Epoch 00080: val_loss did not improve from 0.54140
# 463/463 [==============================] - 169s 365ms/step - loss: 0.5417 - val_loss: 0.5418
# Epoch 81/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5416
# Epoch 00081: val_loss did not improve from 0.54140
# 463/463 [==============================] - 169s 366ms/step - loss: 0.5416 - val_loss: 0.5414
# Epoch 82/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5415
# Epoch 00082: val_loss did not improve from 0.54140
# 463/463 [==============================] - 170s 367ms/step - loss: 0.5415 - val_loss: 0.5415
# Epoch 83/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5415
# Epoch 00083: val_loss improved from 0.54140 to 0.54132, saving model to autoencoderv5/checkpoint/model.83-0.541.h5
# 463/463 [==============================] - 169s 366ms/step - loss: 0.5415 - val_loss: 0.5413
# Epoch 84/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5414
# Epoch 00084: val_loss did not improve from 0.54132
# 463/463 [==============================] - 170s 367ms/step - loss: 0.5414 - val_loss: 0.5416
# Epoch 85/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5415
# Epoch 00085: val_loss did not improve from 0.54132
# 463/463 [==============================] - 170s 367ms/step - loss: 0.5415 - val_loss: 0.5433
# Epoch 86/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5415
# Epoch 00086: val_loss did not improve from 0.54132
# 463/463 [==============================] - 170s 367ms/step - loss: 0.5415 - val_loss: 0.5414
# Epoch 87/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5413
# Epoch 00087: val_loss did not improve from 0.54132
# 463/463 [==============================] - 172s 370ms/step - loss: 0.5413 - val_loss: 0.5416
# Epoch 88/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5413
# Epoch 00088: val_loss did not improve from 0.54132
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5413 - val_loss: 0.5413
# Epoch 89/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5413
# Epoch 00089: val_loss improved from 0.54132 to 0.54101, saving model to autoencoderv5/checkpoint/model.89-0.541.h5
# 463/463 [==============================] - 170s 368ms/step - loss: 0.5413 - val_loss: 0.5410
# Epoch 90/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5413
# Epoch 00090: val_loss did not improve from 0.54101
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5413 - val_loss: 0.5415
# Epoch 91/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5413
# Epoch 00091: val_loss did not improve from 0.54101
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5413 - val_loss: 0.5413
# Epoch 92/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5412
# Epoch 00092: val_loss did not improve from 0.54101
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5412 - val_loss: 0.5414
# Epoch 93/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5412
# Epoch 00093: val_loss did not improve from 0.54101
# 463/463 [==============================] - 171s 369ms/step - loss: 0.5412 - val_loss: 0.5428
# Epoch 94/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5412
# Epoch 00094: val_loss did not improve from 0.54101
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5412 - val_loss: 0.5414
# Epoch 95/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5411
# Epoch 00095: val_loss improved from 0.54101 to 0.54075, saving model to autoencoderv5/checkpoint/model.95-0.541.h5
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5411 - val_loss: 0.5407
# Epoch 96/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5411
# Epoch 00096: val_loss did not improve from 0.54075
# 463/463 [==============================] - 170s 368ms/step - loss: 0.5411 - val_loss: 0.5410
# Epoch 97/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5411
# Epoch 00097: val_loss did not improve from 0.54075
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5411 - val_loss: 0.5425
# Epoch 98/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5411
# Epoch 00098: val_loss did not improve from 0.54075
# 463/463 [==============================] - 171s 368ms/step - loss: 0.5411 - val_loss: 0.5409
# Epoch 99/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5410
# Epoch 00099: val_loss did not improve from 0.54075
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5410 - val_loss: 0.5408
# Epoch 100/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5410
# Epoch 00100: val_loss did not improve from 0.54075
# 463/463 [==============================] - 208s 450ms/step - loss: 0.5410 - val_loss: 0.5413
# Wall time: 5h 29min 6s

# %%
# %%time
encoded_imgs = encoder.predict(val_data)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Wall time: 2.04 s

# %%
# %%time
# result of training with dropout after maxpool and upsample and test them with dropouts removed
import matplotlib.pyplot as plt # use plt.gray() for grayscale, default is viridis
import numpy as np
import math
import cv2

input_shape = (64, 64, 3)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(val_data[i].reshape(input_shape))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(decoded_imgs[i].reshape(input_shape))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# https://dsp.stackexchange.com/questions/38065/peak-signal-to-noise-ratio-psnr-in-python-for-an-image
def mse(img1, img2):
    return np.mean( (img1 - img2) ** 2 )

def psnr(img1, img2):
    mserr = mse(img1, img2)
    PIXEL_MAX = 1.0
    try:
        return 20 * math.log10(PIXEL_MAX / math.sqrt(mserr))
    except ZeroDivisionError:
        return 'Same image'

n = 10
for i in range(n):
    original = val_data[i]
    contrast = decoded_imgs[i]
    a = mse(original, contrast)
    b = psnr(original, contrast) # can also use cv2.PSNR rather than defined function psnr
    if b != 'Same image':
        print(f'MSE = {a:.4f}, PSNR (dB) = {b:.2f}')
    else:
        print(f'MSE = {a:.4f}, PSNR too high')
# Out:
# MSE = 0.0044, PSNR (dB) = 23.52
# MSE = 0.0082, PSNR (dB) = 20.88
# MSE = 0.0045, PSNR (dB) = 23.47
# MSE = 0.0089, PSNR (dB) = 20.52
# MSE = 0.0034, PSNR (dB) = 24.73
# MSE = 0.0071, PSNR (dB) = 21.47
# MSE = 0.0031, PSNR (dB) = 25.15
# MSE = 0.0080, PSNR (dB) = 20.97
# MSE = 0.0047, PSNR (dB) = 23.25
# MSE = 0.0128, PSNR (dB) = 18.93
# Wall time: 1.1 s

# %%
# %%time
# https://github.com/imamun93/Image-Similarities-using-SSIM/blob/master/blog5_ssim.ipynb
import numpy as np
from tensorflow.image import ssim
from tensorflow import convert_to_tensor

n = 10
for i in range(n):
    original = val_data[i].reshape(1, 64, 64, 3)
    contrast = decoded_imgs[i].reshape(1, 64, 64, 3)
    a = np.asarray(ssim(convert_to_tensor(original), convert_to_tensor(contrast), max_val=1)) # <class 'tensorflow.python.framework.ops.EagerTensor'>
    print(f'{a[0]:.4f}')
# Out:
# 0.6641
# 0.6831
# 0.5675
# 0.6054
# 0.6243
# 0.7652
# 0.7761
# 0.5204
# 0.6282
# 0.4898
# Wall time: 649 ms

# %%
# %%time
# https://github.com/tensorflow/models/blob/master/research/compression/image_encoder/msssim.py
import numpy as np
from scipy import signal
from scipy.ndimage.filters import convolve

def _FSpecialGauss(size, sigma):
  """Function to mimic the 'fspecial' gaussian MATLAB function."""
  radius = size // 2
  offset = 0.0
  start, stop = -radius, radius + 1
  if size % 2 == 0:
    offset = 0.5
    stop -= 1
  x, y = np.mgrid[offset + start:stop, offset + start:stop]
  assert len(x) == size
  g = np.exp(-((x**2 + y**2)/(2.0 * sigma**2)))
  return g / g.sum()


def _SSIMForMultiScale(img1, img2, max_val=255, filter_size=11,
                       filter_sigma=1.5, k1=0.01, k2=0.03):
  """Return the Structural Similarity Map between `img1` and `img2`.
  This function attempts to match the functionality of ssim_index_new.m by
  Zhou Wang: http://www.cns.nyu.edu/~lcv/ssim/msssim.zip
  Arguments:
    img1: Numpy array holding the first RGB image batch.
    img2: Numpy array holding the second RGB image batch.
    max_val: the dynamic range of the images (i.e., the difference between the
      maximum the and minimum allowed values).
    filter_size: Size of blur kernel to use (will be reduced for small images).
    filter_sigma: Standard deviation for Gaussian blur kernel (will be reduced
      for small images).
    k1: Constant used to maintain stability in the SSIM calculation (0.01 in
      the original paper).
    k2: Constant used to maintain stability in the SSIM calculation (0.03 in
      the original paper).
  Returns:
    Pair containing the mean SSIM and contrast sensitivity between `img1` and
    `img2`.
  Raises:
    RuntimeError: If input images don't have the same shape or don't have four
      dimensions: [batch_size, height, width, depth].
  """
  if img1.shape != img2.shape:
    raise RuntimeError('Input images must have the same shape (%s vs. %s).',
                       img1.shape, img2.shape)
  if img1.ndim != 4:
    raise RuntimeError('Input images must have four dimensions, not %d',
                       img1.ndim)

  img1 = img1.astype(np.float64)
  img2 = img2.astype(np.float64)
  _, height, width, _ = img1.shape

  # Filter size can't be larger than height or width of images.
  size = min(filter_size, height, width)

  # Scale down sigma if a smaller filter size is used.
  sigma = size * filter_sigma / filter_size if filter_size else 0

  if filter_size:
    window = np.reshape(_FSpecialGauss(size, sigma), (1, size, size, 1))
    mu1 = signal.fftconvolve(img1, window, mode='valid')
    mu2 = signal.fftconvolve(img2, window, mode='valid')
    sigma11 = signal.fftconvolve(img1 * img1, window, mode='valid')
    sigma22 = signal.fftconvolve(img2 * img2, window, mode='valid')
    sigma12 = signal.fftconvolve(img1 * img2, window, mode='valid')
  else:
    # Empty blur kernel so no need to convolve.
    mu1, mu2 = img1, img2
    sigma11 = img1 * img1
    sigma22 = img2 * img2
    sigma12 = img1 * img2

  mu11 = mu1 * mu1
  mu22 = mu2 * mu2
  mu12 = mu1 * mu2
  sigma11 -= mu11
  sigma22 -= mu22
  sigma12 -= mu12

  # Calculate intermediate values used by both ssim and cs_map.
  c1 = (k1 * max_val) ** 2
  c2 = (k2 * max_val) ** 2
  v1 = 2.0 * sigma12 + c2
  v2 = sigma11 + sigma22 + c2
  ssim = np.mean((((2.0 * mu12 + c1) * v1) / ((mu11 + mu22 + c1) * v2)))
  cs = np.mean(v1 / v2)
  return ssim, cs


def MultiScaleSSIM(img1, img2, max_val=255, filter_size=11, filter_sigma=1.5,
                   k1=0.01, k2=0.03, weights=None):
  """Return the MS-SSIM score between `img1` and `img2`.
  This function implements Multi-Scale Structural Similarity (MS-SSIM) Image
  Quality Assessment according to Zhou Wang's paper, "Multi-scale structural
  similarity for image quality assessment" (2003).
  Link: https://ece.uwaterloo.ca/~z70wang/publications/msssim.pdf
  Author's MATLAB implementation:
  http://www.cns.nyu.edu/~lcv/ssim/msssim.zip
  Arguments:
    img1: Numpy array holding the first RGB image batch.
    img2: Numpy array holding the second RGB image batch.
    max_val: the dynamic range of the images (i.e., the difference between the
      maximum the and minimum allowed values).
    filter_size: Size of blur kernel to use (will be reduced for small images).
    filter_sigma: Standard deviation for Gaussian blur kernel (will be reduced
      for small images).
    k1: Constant used to maintain stability in the SSIM calculation (0.01 in
      the original paper).
    k2: Constant used to maintain stability in the SSIM calculation (0.03 in
      the original paper).
    weights: List of weights for each level; if none, use five levels and the
      weights from the original paper.
  Returns:
    MS-SSIM score between `img1` and `img2`.
  Raises:
    RuntimeError: If input images don't have the same shape or don't have four
      dimensions: [batch_size, height, width, depth].
  """
  if img1.shape != img2.shape:
    raise RuntimeError('Input images must have the same shape (%s vs. %s).',
                       img1.shape, img2.shape)
  if img1.ndim != 4:
    raise RuntimeError('Input images must have four dimensions, not %d',
                       img1.ndim)

  # Note: default weights don't sum to 1.0 but do match the paper / matlab code.
  weights = np.array(weights if weights else
                     [0.0448, 0.2856, 0.3001, 0.2363, 0.1333])
  levels = weights.size
  downsample_filter = np.ones((1, 2, 2, 1)) / 4.0
  im1, im2 = [x.astype(np.float64) for x in [img1, img2]]
  mssim = np.array([])
  mcs = np.array([])
  for _ in range(levels):
    ssim, cs = _SSIMForMultiScale(
        im1, im2, max_val=max_val, filter_size=filter_size,
        filter_sigma=filter_sigma, k1=k1, k2=k2)
    mssim = np.append(mssim, ssim)
    mcs = np.append(mcs, cs)
    filtered = [convolve(im, downsample_filter, mode='reflect')
                for im in [im1, im2]]
    im1, im2 = [x[:, ::2, ::2, :] for x in filtered]
  return (np.prod(mcs[0:levels-1] ** weights[0:levels-1]) *
          (mssim[levels-1] ** weights[levels-1]))

n = 10
for i in range(n):
    original = val_data[i].reshape(1, 64, 64, 3)
    contrast = decoded_imgs[i].reshape(1, 64, 64, 3)
    d=MultiScaleSSIM(original, contrast, max_val=1)
    print(f'{d:.4f}')
# Out:
# 0.9102
# 0.9408
# 0.8990
# 0.9206
# 0.8965
# 0.9361
# 0.9420
# 0.8883
# 0.8940
# 0.8476
# Wall time: 5.23 s

# %%
# %%time
import os

try:
    os.makedirs("autoencoderv5/model")
except Exception:
    pass

save_model(autoencoder, "autoencoderv5/model/autoencoderv5-64-32-16-16-16-16-32-64.h5")
save_model(encoder, "autoencoderv5/model/encoderv5-64-32-16-16.h5")
save_model(decoder, "autoencoderv5/model/decoderv5-16-16-32-64.h5")
# Out:
# Wall time: 90.3 ms

# %%
autoencoder = load_model("autoencoderv5/model/autoencoderv5-64-32-16-16-16-16-32-64.h5")
encoder = load_model("autoencoderv5/model/encoderv5-64-32-16-16.h5")
decoder = load_model("autoencoderv5/model/decoderv5-16-16-32-64.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
