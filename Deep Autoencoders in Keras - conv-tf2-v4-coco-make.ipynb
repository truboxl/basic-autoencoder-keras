# %%
import tensorflow as tf
Model           = tf.keras.models.Model
Input           = tf.keras.layers.Input
Dense           = tf.keras.layers.Dense
Conv2D          = tf.keras.layers.Conv2D
MaxPooling2D    = tf.keras.layers.MaxPooling2D
UpSampling2D    = tf.keras.layers.UpSampling2D
save_model      = tf.keras.models.save_model
load_model      = tf.keras.models.load_model
#load_img        = tf.keras.preprocessing.image.load_img # pip install pillow or import PIL
#img_to_array    = tf.keras.preprocessing.image.img_to_array
TensorBoard     = tf.keras.callbacks.TensorBoard
ModelCheckpoint = tf.keras.callbacks.ModelCheckpoint

# %%
# https://www.pyimagesearch.com/2018/12/31/keras-conv2d-and-convolutional-layers/
# Conv2D(batch_size, (input_shape), activation, padding) # more batch size in deeper layer
# MaxPooling2D((input_shape), padding) # padding 'valid' = no padding, padding 'same' = preserve dimension + padding

# Autoencoder Architecture
input_img = Input(shape=(64, 64, 3)) # change this to other than 28*28 may show "multiple" shape
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x) # at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x) # may want to intentionally drop padding here for other shape
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded, name='autoencoder')
autoencoder.compile(optimizer='adam', loss='binary_crossentropy') # use binary_crossentropy, mean_squared_error doesnt work

# Encoder Model
encoder = Model(input_img, encoded, name='encoder')

# Decoder Architecture
Dlayer_input = Input(shape=(8,8,8)) # use model.summary() to check
x = autoencoder.layers[-7](Dlayer_input)
x = autoencoder.layers[-6](x)
x = autoencoder.layers[-5](x)
x = autoencoder.layers[-4](x)
x = autoencoder.layers[-3](x)
x = autoencoder.layers[-2](x)
Dlayer_output = autoencoder.layers[-1](x) # extract last layer

# Decoder Model
decoder = Model(Dlayer_input, Dlayer_output, name='decoder')

# %%
autoencoder.summary()
encoder.summary()
decoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 16)        1168
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         867
# =================================================================
# Total params: 13,939
# Trainable params: 13,939
# Non-trainable params: 0
# _________________________________________________________________
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 8)           0
# =================================================================
# Total params: 6,680
# Trainable params: 6,680
# Non-trainable params: 0
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 8, 8, 8)]         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 16)        1168
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 3)         867
# =================================================================
# Total params: 7,259
# Trainable params: 7,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
def make_square(img):
    cols,rows = img.size
    
    if rows>cols:
        pad = (rows-cols)/4
        img = img.crop((0, pad, cols, cols+pad)) # left, up, right, down
    else:
        pad = (cols-rows)/4
        img = img.crop((pad, 0, rows+pad, rows))
    
    return img # make centered square image

# %%
# %%time
# Check training dataset image
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display

path_train = r"D:\Public\fyp-code\datasets\coco\train2017-2"

train_data = []

for img in sorted(os.listdir(path_train)):
    #print(img) # show which image file currently used
    
    # Keras builtin (not used)
    #x = load_img(os.path.join(path_train,img), target_size=(128,128), color_mode='grayscale') 
    #x = img_to_array(x)
    
    # PIL (use this)
    x = Image.open(os.path.join(path_train,img))
    display(x) # show training image
    print("Original image size is " + str(x.size))
    x = make_square(x)
    display(x) # show square image
    print("Squared image size is " + str(x.size))
    x = x.resize((128,128)) # TAKE NOTE
    x = np.asarray(x)
    x = x.astype('float32')/255
    train_data.append(np.asarray(x)) # can take a long time
    print(str(len(train_data)) + " of " + str(len(os.listdir(path_train))))
    break

print("train_data type is " + str(type(train_data)))
print("train_data shape is "+ str(np.asarray(train_data).shape)) # type list has no shape, must be in type array # (1, 128, 128, 3)
print("image type in train_data is " + str(type(train_data[0])))
plt.imshow(np.squeeze(train_data[0])) # show resized 1st image
plt.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x229527DFD88>
# Original image size is (640, 480)
# <PIL.Image.Image image mode=RGB size=480x480 at 0x229527DFCC8>
# Squared image size is (480, 480)
# 1 of 14785
# train_data type is <class 'list'>
# train_data shape is (1, 128, 128, 3)
# image type in train_data is <class 'numpy.ndarray'>
# Wall time: 1.17 s

# %%
# Refer "Dataset Preprocess to Pickle - COCO train2017.ipynb" for data preprocess
# We will directly load preprocessed datasets rather than load jpg one by one

# %%
# %%time
import pickle as pkl

with open("datasets_coco_train2017.pkl", 'rb') as handle:
    train_data = pkl.load(handle)

print("Done")

with open("datasets_coco_test2017.pkl", 'rb') as handle:
    test_data = pkl.load(handle)

print("Done")

with open("datasets_coco_val2017.pkl", 'rb') as handle:
    val_data = pkl.load(handle)

print("Done")
# Out:
# Done
# Done
# Done
# Wall time: 1.21 s

# %%
# %%time
#train_data = np.reshape(train_data, (len(train_data), 128, 128, 3))
#test_data = np.reshape(test_data, (len(test_data), 128, 128, 3))
#val_data = np.reshape(val_data, (len(val_data), 128, 128, 3))
print(train_data.shape)
print(test_data.shape)
print(val_data.shape)
# Out:
# (14785, 64, 64, 3)
# (5083, 64, 64, 3)
# (625, 64, 64, 3)
# Wall time: 0 ns

# %%
# %%time
#import os
#os.listdir("autoencoderv4/checkpoint")

# Resume by load model (example)
#autoencoder = load_model("autoencoderv4/checkpoint/model.02-0.53.h5") # use this
#latest = tf.train.latest_checkpoint("autoencoderv4/checkpoint") # TODO
# Out:
# Wall time: 0 ns

# %%
# %%time
import os

try:
    os.makedirs("autoencoderv4/logs")
except Exception:
    pass

try:
    os.makedirs("autoencoderv4/checkpoint")
except Exception:
    pass

# Run this in a terminal
#tensorboard --logdir=autoencoderv4/logs

callbacks=[
    TensorBoard(log_dir='autoencoderv4/logs'),
    ModelCheckpoint(filepath='autoencoderv4/checkpoint/model.{epoch:02d}-{val_loss:.3f}.h5',
                    verbose=1, save_best_only=True, mode='min')
]

# Fit data # If it takes a long time to show Epoch 1, check your input shape # WARINING: RAM will rise
autoencoder.fit(train_data, train_data,
                epochs=100, batch_size=32, shuffle=True,
                validation_data=(test_data, test_data),
                callbacks=callbacks)
# Out:
# Epoch 1/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5517
# Epoch 00001: val_loss improved from inf to 0.55134, saving model to autoencoderv4/checkpoint/model.01-0.55.h5
# 463/463 [==============================] - 204s 441ms/step - loss: 0.5517 - val_loss: 0.5513
# Epoch 2/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5514
# Epoch 00002: val_loss did not improve from 0.55134
# 463/463 [==============================] - 206s 446ms/step - loss: 0.5514 - val_loss: 0.6491
# Epoch 3/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5610
# Epoch 00003: val_loss did not improve from 0.55134
# 463/463 [==============================] - 206s 445ms/step - loss: 0.5610 - val_loss: 0.5670
# Epoch 4/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5525
# Epoch 00004: val_loss did not improve from 0.55134
# 463/463 [==============================] - 212s 457ms/step - loss: 0.5525 - val_loss: 0.5520
# Epoch 5/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5515
# Epoch 00005: val_loss did not improve from 0.55134
# 463/463 [==============================] - 194s 419ms/step - loss: 0.5515 - val_loss: 0.5555
# Epoch 6/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5512
# Epoch 00006: val_loss improved from 0.55134 to 0.55126, saving model to autoencoderv4/checkpoint/model.06-0.55.h5
# 463/463 [==============================] - 182s 393ms/step - loss: 0.5512 - val_loss: 0.5513
# Epoch 7/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5509
# Epoch 00007: val_loss improved from 0.55126 to 0.55046, saving model to autoencoderv4/checkpoint/model.07-0.55.h5
# 463/463 [==============================] - 181s 390ms/step - loss: 0.5509 - val_loss: 0.5505
# Epoch 8/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5506
# Epoch 00008: val_loss did not improve from 0.55046
# 463/463 [==============================] - 184s 397ms/step - loss: 0.5506 - val_loss: 0.5513
# Epoch 9/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5504
# Epoch 00009: val_loss improved from 0.55046 to 0.54985, saving model to autoencoderv4/checkpoint/model.09-0.55.h5
# 463/463 [==============================] - 177s 383ms/step - loss: 0.5504 - val_loss: 0.5499
# Epoch 10/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5501
# Epoch 00010: val_loss did not improve from 0.54985
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5501 - val_loss: 0.5529
# Epoch 11/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5500
# Epoch 00011: val_loss improved from 0.54985 to 0.54945, saving model to autoencoderv4/checkpoint/model.11-0.55.h5
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5500 - val_loss: 0.5494
# Epoch 12/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5497
# Epoch 00012: val_loss did not improve from 0.54945
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5498 - val_loss: 0.5509
# Epoch 13/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5496
# Epoch 00013: val_loss improved from 0.54945 to 0.54923, saving model to autoencoderv4/checkpoint/model.13-0.55.h5
# 463/463 [==============================] - 174s 377ms/step - loss: 0.5496 - val_loss: 0.5492
# Epoch 14/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5494
# Epoch 00014: val_loss improved from 0.54923 to 0.54880, saving model to autoencoderv4/checkpoint/model.14-0.55.h5
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5494 - val_loss: 0.5488
# Epoch 15/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5492
# Epoch 00015: val_loss did not improve from 0.54880
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5492 - val_loss: 0.5495
# Epoch 16/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5491
# Epoch 00016: val_loss did not improve from 0.54880
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5491 - val_loss: 0.5493
# Epoch 17/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5490
# Epoch 00017: val_loss did not improve from 0.54880
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5490 - val_loss: 0.5518
# Epoch 18/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5489
# Epoch 00018: val_loss did not improve from 0.54880
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5488 - val_loss: 0.5491
# Epoch 19/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5487
# Epoch 00019: val_loss did not improve from 0.54880
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5487 - val_loss: 0.5501
# Epoch 20/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5486
# Epoch 00020: val_loss improved from 0.54880 to 0.54827, saving model to autoencoderv4/checkpoint/model.20-0.55.h5
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5486 - val_loss: 0.5483
# Epoch 21/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5485
# Epoch 00021: val_loss did not improve from 0.54827
# 463/463 [==============================] - 174s 377ms/step - loss: 0.5485 - val_loss: 0.5540
# Epoch 22/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5484
# Epoch 00022: val_loss did not improve from 0.54827
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5484 - val_loss: 0.5496
# Epoch 23/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5482
# Epoch 00023: val_loss did not improve from 0.54827
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5482 - val_loss: 0.5489
# Epoch 24/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5481
# Epoch 00024: val_loss improved from 0.54827 to 0.54771, saving model to autoencoderv4/checkpoint/model.24-0.55.h5
# 463/463 [==============================] - 176s 380ms/step - loss: 0.5481 - val_loss: 0.5477
# Epoch 25/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 00025: val_loss did not improve from 0.54771
# 463/463 [==============================] - 176s 380ms/step - loss: 0.5480 - val_loss: 0.5479
# Epoch 26/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 00026: val_loss did not improve from 0.54771
# 463/463 [==============================] - 181s 392ms/step - loss: 0.5480 - val_loss: 0.5482
# Epoch 27/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5479
# Epoch 00027: val_loss improved from 0.54771 to 0.54736, saving model to autoencoderv4/checkpoint/model.27-0.55.h5
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5479 - val_loss: 0.5474
# Epoch 28/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5478
# Epoch 00028: val_loss did not improve from 0.54736
# 463/463 [==============================] - 175s 377ms/step - loss: 0.5478 - val_loss: 0.5477
# Epoch 29/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5477
# Epoch 00029: val_loss improved from 0.54736 to 0.54730, saving model to autoencoderv4/checkpoint/model.29-0.55.h5
# 463/463 [==============================] - 180s 389ms/step - loss: 0.5477 - val_loss: 0.5473
# Epoch 30/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5477
# Epoch 00030: val_loss did not improve from 0.54730
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5477 - val_loss: 0.5526
# Epoch 31/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5476
# Epoch 00031: val_loss did not improve from 0.54730
# 463/463 [==============================] - 174s 377ms/step - loss: 0.5476 - val_loss: 0.5479
# Epoch 32/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5475
# Epoch 00032: val_loss improved from 0.54730 to 0.54726, saving model to autoencoderv4/checkpoint/model.32-0.55.h5
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5475 - val_loss: 0.5473
# Epoch 33/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5475
# Epoch 00033: val_loss improved from 0.54726 to 0.54701, saving model to autoencoderv4/checkpoint/model.33-0.55.h5
# 463/463 [==============================] - 177s 383ms/step - loss: 0.5475 - val_loss: 0.5470
# Epoch 34/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5474
# Epoch 00034: val_loss did not improve from 0.54701
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5474 - val_loss: 0.5470
# Epoch 35/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5473
# Epoch 00035: val_loss improved from 0.54701 to 0.54685, saving model to autoencoderv4/checkpoint/model.35-0.55.h5
# 463/463 [==============================] - 176s 379ms/step - loss: 0.5473 - val_loss: 0.5469
# Epoch 36/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5473
# Epoch 00036: val_loss did not improve from 0.54685
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5473 - val_loss: 0.5479
# Epoch 37/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5472
# Epoch 00037: val_loss did not improve from 0.54685
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5472 - val_loss: 0.5471
# Epoch 38/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5472
# Epoch 00038: val_loss did not improve from 0.54685
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5472 - val_loss: 0.5481
# Epoch 39/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5471
# Epoch 00039: val_loss did not improve from 0.54685
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5471 - val_loss: 0.5470
# Epoch 40/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00040: val_loss improved from 0.54685 to 0.54671, saving model to autoencoderv4/checkpoint/model.40-0.55.h5
# 463/463 [==============================] - 176s 379ms/step - loss: 0.5470 - val_loss: 0.5467
# Epoch 41/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00041: val_loss did not improve from 0.54671
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5470 - val_loss: 0.5470
# Epoch 42/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00042: val_loss did not improve from 0.54671
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5470 - val_loss: 0.5471
# Epoch 43/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 00043: val_loss did not improve from 0.54671
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5470 - val_loss: 0.5477
# Epoch 44/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5469
# Epoch 00044: val_loss did not improve from 0.54671
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5469 - val_loss: 0.5470
# Epoch 45/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5469
# Epoch 00045: val_loss improved from 0.54671 to 0.54654, saving model to autoencoderv4/checkpoint/model.45-0.55.h5
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5469 - val_loss: 0.5465
# Epoch 46/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 00046: val_loss did not improve from 0.54654
# 463/463 [==============================] - 174s 376ms/step - loss: 0.5468 - val_loss: 0.5472
# Epoch 47/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 00047: val_loss did not improve from 0.54654
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5468 - val_loss: 0.5471
# Epoch 48/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 00048: val_loss did not improve from 0.54654
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5468 - val_loss: 0.5466
# Epoch 49/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 00049: val_loss did not improve from 0.54654
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5468 - val_loss: 0.5474
# Epoch 50/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5467
# Epoch 00050: val_loss did not improve from 0.54654
# 463/463 [==============================] - 176s 379ms/step - loss: 0.5467 - val_loss: 0.5470
# Epoch 51/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5466
# Epoch 00051: val_loss improved from 0.54654 to 0.54631, saving model to autoencoderv4/checkpoint/model.51-0.55.h5
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5466 - val_loss: 0.5463
# Epoch 52/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5466
# Epoch 00052: val_loss did not improve from 0.54631
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5466 - val_loss: 0.5463
# Epoch 53/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5466
# Epoch 00053: val_loss improved from 0.54631 to 0.54614, saving model to autoencoderv4/checkpoint/model.53-0.55.h5
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5466 - val_loss: 0.5461
# Epoch 54/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00054: val_loss did not improve from 0.54614
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5465 - val_loss: 0.5473
# Epoch 55/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00055: val_loss did not improve from 0.54614
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5465 - val_loss: 0.5462
# Epoch 56/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00056: val_loss did not improve from 0.54614
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5465 - val_loss: 0.5462
# Epoch 57/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00057: val_loss did not improve from 0.54614
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5465 - val_loss: 0.5471
# Epoch 58/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00058: val_loss did not improve from 0.54614
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5465 - val_loss: 0.5478
# Epoch 59/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 00059: val_loss improved from 0.54614 to 0.54600, saving model to autoencoderv4/checkpoint/model.59-0.55.h5
# 463/463 [==============================] - 174s 375ms/step - loss: 0.5465 - val_loss: 0.5460
# Epoch 60/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 00060: val_loss did not improve from 0.54600
# 463/463 [==============================] - 176s 380ms/step - loss: 0.5464 - val_loss: 0.5464
# Epoch 61/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00061: val_loss did not improve from 0.54600
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5464 - val_loss: 0.5480
# Epoch 62/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 00062: val_loss did not improve from 0.54600
# 463/463 [==============================] - 174s 377ms/step - loss: 0.5464 - val_loss: 0.5477
# Epoch 63/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 00063: val_loss did not improve from 0.54600
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5463 - val_loss: 0.5484
# Epoch 64/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 00064: val_loss did not improve from 0.54600
# 463/463 [==============================] - 171s 370ms/step - loss: 0.5463 - val_loss: 0.5461
# Epoch 65/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 00065: val_loss did not improve from 0.54600
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5463 - val_loss: 0.5468
# Epoch 66/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 00066: val_loss did not improve from 0.54600
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5462 - val_loss: 0.5474
# Epoch 67/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 00067: val_loss did not improve from 0.54600
# 463/463 [==============================] - 175s 378ms/step - loss: 0.5462 - val_loss: 0.5472
# Epoch 68/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 00068: val_loss improved from 0.54600 to 0.54573, saving model to autoencoderv4/checkpoint/model.68-0.55.h5
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5462 - val_loss: 0.5457
# Epoch 69/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5461
# Epoch 00069: val_loss did not improve from 0.54573
# 463/463 [==============================] - 172s 371ms/step - loss: 0.5461 - val_loss: 0.5462
# Epoch 70/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5461
# Epoch 00070: val_loss did not improve from 0.54573
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5461 - val_loss: 0.5458
# Epoch 71/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5461
# Epoch 00071: val_loss did not improve from 0.54573
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5461 - val_loss: 0.5461
# Epoch 72/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5461
# Epoch 00072: val_loss did not improve from 0.54573
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5461 - val_loss: 0.5466
# Epoch 73/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00073: val_loss did not improve from 0.54573
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5460 - val_loss: 0.5458
# Epoch 74/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00074: val_loss did not improve from 0.54573
# 463/463 [==============================] - 179s 386ms/step - loss: 0.5460 - val_loss: 0.5467
# Epoch 75/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00075: val_loss did not improve from 0.54573
# 463/463 [==============================] - 172s 372ms/step - loss: 0.5460 - val_loss: 0.5480
# Epoch 76/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 00076: val_loss improved from 0.54573 to 0.54557, saving model to autoencoderv4/checkpoint/model.76-0.55.h5
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5460 - val_loss: 0.5456
# Epoch 77/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5459
# Epoch 00077: val_loss did not improve from 0.54557
# 463/463 [==============================] - 171s 369ms/step - loss: 0.5460 - val_loss: 0.5458
# Epoch 78/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5459
# Epoch 00078: val_loss did not improve from 0.54557
# 463/463 [==============================] - 177s 382ms/step - loss: 0.5459 - val_loss: 0.5465
# Epoch 79/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5459
# Epoch 00079: val_loss did not improve from 0.54557
# 463/463 [==============================] - 178s 384ms/step - loss: 0.5459 - val_loss: 0.5462
# Epoch 80/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5458
# Epoch 00080: val_loss did not improve from 0.54557
# 463/463 [==============================] - 177s 383ms/step - loss: 0.5459 - val_loss: 0.5459
# Epoch 81/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5459
# Epoch 00081: val_loss did not improve from 0.54557
# 463/463 [==============================] - 176s 380ms/step - loss: 0.5458 - val_loss: 0.5495
# Epoch 82/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5458
# Epoch 00082: val_loss did not improve from 0.54557
# 463/463 [==============================] - 176s 379ms/step - loss: 0.5458 - val_loss: 0.5456
# Epoch 83/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 00083: val_loss improved from 0.54557 to 0.54547, saving model to autoencoderv4/checkpoint/model.83-0.55.h5
# 463/463 [==============================] - 178s 384ms/step - loss: 0.5457 - val_loss: 0.5455
# Epoch 84/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 00084: val_loss did not improve from 0.54547
# 463/463 [==============================] - 177s 383ms/step - loss: 0.5457 - val_loss: 0.5500
# Epoch 85/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 00085: val_loss improved from 0.54547 to 0.54529, saving model to autoencoderv4/checkpoint/model.85-0.55.h5
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5457 - val_loss: 0.5453
# Epoch 86/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 00086: val_loss did not improve from 0.54529
# 463/463 [==============================] - 177s 382ms/step - loss: 0.5457 - val_loss: 0.5463
# Epoch 87/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5456
# Epoch 00087: val_loss did not improve from 0.54529
# 463/463 [==============================] - 176s 381ms/step - loss: 0.5456 - val_loss: 0.5466
# Epoch 88/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5456
# Epoch 00088: val_loss did not improve from 0.54529
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5456 - val_loss: 0.5461
# Epoch 89/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5456
# Epoch 00089: val_loss did not improve from 0.54529
# 463/463 [==============================] - 179s 386ms/step - loss: 0.5456 - val_loss: 0.5473
# Epoch 90/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5455
# Epoch 00090: val_loss did not improve from 0.54529
# 463/463 [==============================] - 175s 379ms/step - loss: 0.5455 - val_loss: 0.5459
# Epoch 91/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5455
# Epoch 00091: val_loss did not improve from 0.54529
# 463/463 [==============================] - 173s 375ms/step - loss: 0.5455 - val_loss: 0.5461
# Epoch 92/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5455
# Epoch 00092: val_loss did not improve from 0.54529
# 463/463 [==============================] - 173s 373ms/step - loss: 0.5455 - val_loss: 0.5459
# Epoch 93/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5455
# Epoch 00093: val_loss did not improve from 0.54529
# 463/463 [==============================] - 173s 374ms/step - loss: 0.5455 - val_loss: 0.5462
# Epoch 94/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00094: val_loss did not improve from 0.54529
# 463/463 [==============================] - 177s 382ms/step - loss: 0.5455 - val_loss: 0.5454
# Epoch 95/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00095: val_loss did not improve from 0.54529
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5454 - val_loss: 0.5458
# Epoch 96/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00096: val_loss did not improve from 0.54529
# 463/463 [==============================] - 179s 386ms/step - loss: 0.5454 - val_loss: 0.5473
# Epoch 97/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00097: val_loss did not improve from 0.54529
# 463/463 [==============================] - 178s 384ms/step - loss: 0.5454 - val_loss: 0.5457
# Epoch 98/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 00098: val_loss improved from 0.54529 to 0.54501, saving model to autoencoderv4/checkpoint/model.98-0.55.h5
# 463/463 [==============================] - 177s 383ms/step - loss: 0.5454 - val_loss: 0.5450
# Epoch 99/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5453
# Epoch 00099: val_loss did not improve from 0.54501
# 463/463 [==============================] - 179s 386ms/step - loss: 0.5453 - val_loss: 0.5464
# Epoch 100/100
# 462/463 [============================>.] - ETA: 0s - loss: 0.5453
# Epoch 00100: val_loss did not improve from 0.54501
# 463/463 [==============================] - 178s 385ms/step - loss: 0.5453 - val_loss: 0.5463
# Wall time: 4h 54min 49s

# %%
# %%time
encoded_imgs = encoder.predict(test_data)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# Wall time: 14.9 s

# %%
# %%time
n = 10
plt.figure(figsize=(20, 4))

for i in range(n):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(test_data[i].reshape(64,64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(64,64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
# Out:
# Wall time: 1.33 s

# %%
# %%time
import numpy as np
import math
import cv2

def psnr(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

n = 10
for i in range(n):
    original = test_data[i]
    contrast = decoded_imgs[i]
    d=psnr(original,contrast)
    print("%.1f" % d)
# Out:
# 67.7
# 69.4
# 66.0
# 69.5
# 70.5
# 65.2
# 69.7
# 71.0
# 67.3
# 68.3
# Wall time: 8 ms

# %%
# %%time
import os

try:
    os.makedirs("autoencoderv4/model")
except Exception:
    pass

save_model(autoencoder, "autoencoderv4/model/autoencoderv4-784-256-128-64-128-256-784.h5")
save_model(encoder, "autoencoderv4/model/encoderv4-784-256-128-64.h5")
save_model(decoder, "autoencoderv4/model/decoderv4-64-128-256-784.h5")
# Out:
# Wall time: 1.82 s
